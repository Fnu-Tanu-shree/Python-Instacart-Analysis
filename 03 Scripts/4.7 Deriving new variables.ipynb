# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
# Defining path
path = r'/Users/tanu/Desktop/Instacart Basket Analysis/02 Data/Prepared data'

# %%
# Importing data set
ords_prods_merge = pd.read_pickle(os.path.join(path,'ords_prods_merge_2.pkl'))

# %%
# Create a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                      2                  8
# 1   2539329        1             1                      2                  8
# 2   2539329        1             1                      2                  8
# 3   2539329        1             1                      2                  8
# 4   2539329        1             1                      2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
# Defining function

def price_label(row):

    if row['prices'] <= 5:
        return 'Low range product'
    elif (row['prices'] >5) and (row['prices'] <= 15):
        return 'Mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return 'Not enough data'

# %%
# Apply the function

df['price_range'] = df.apply(price_label, axis = 1)
# Out:
# /var/folders/tn/7968l_p11wbcjd89795bwnb40000gn/T/ipykernel_53054/4221219494.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid range product     673340
# Low range product     314392
# High range product     12268
# Name: count, dtype: int64

# %%
# Define function with loc
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Apply the function
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     673340
# Low-range product     314392
# High-range product     12268
# Name: count, dtype: int64

# %%
#Apply the loc function on whole data set
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21865987
# Low-range product     10126321
# High-range product      412551
# Name: count, dtype: int64

# %%
ords_prods_merge['order_day_of_the_week'].value_counts(dropna = False)
# Out:
# order_day_of_the_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# Saturday is the busiest day followed by monday. Wednesday is the slowest of all days for instacart app orders

# %%
# Loop for busiest day

result = []
for value in ords_prods_merge["order_day_of_the_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regular busy")

# %%
result
# Out:
# ['Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regular busy    22416875
# Busiest day      6204182
# Least busy       3783802
# Name: count, dtype: int64

# %% [markdown]
# # TASK

# %% [markdown]
# # Step 2. Create Busiest days(consider 2 busy days) and Slowesy days (consider 2 least busy days)

# %%
result = []

for value in ords_prods_merge["order_day_of_the_week"]:
    if value == 0 or value == 1:
        result.append("Busiest days")
    elif value == 3 or value == 4:
        result.append("Least busy days")
    else:
        result.append("Regularly busy")

# %%
# check the result
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Least busy days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
# creating the column
ords_prods_merge['Busiest_days'] = result

# %% [markdown]
# # Step 3. check the new column for accuracy

# %%
# checking the result
ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Busiest_days
# Regularly busy     12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: count, dtype: int64

# %% [markdown]
# Total number of rows are same in both the columns,which is equal to 32404859, mean all rows have been called/checked

# %% [markdown]
# # Step 4 , Find out busiest period of time

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                      2                  8
# 1   2539329        1             1                      2                  8
# 2   2539329        1             1                      2                  8
# 3   2539329        1             1                      2                  8
# 4   2539329        1             1                      2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
# frequency for each hour
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# Dividing hours in periods of time, 'Most ordser','Average orders'and 'Fewest orders'.
# Since there are 24 hours we will devide them in 3 sections with 8 hours in each.

# %%
result = []

for value in ords_prods_merge["order_hour_of_day"]:
    if value == 10 or value == 11 or value ==14 or value == 15 or value == 13 or value == 12 or value == 16 or value == 9:
        result.append("Most orders")
    elif value == 17 or value == 8 or value == 18 or value == 19 or value == 20 or value == 7 or value ==21 or value == 22:
        result.append("Average orders")
    else:
        result.append("Fewest orders")

# %%
result
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
# Naming the column
ords_prods_merge['Busiest_period_of_day'] = result

# %% [markdown]
# # Step 5: Print the frequency of new column

# %%
ords_prods_merge['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
# Since totla frequency is 32404859, all rows are checked.

# %% [markdown]
# # Export the dataframe

# %%
ords_prods_merge.to_pickle(os.path.join(path,'ords_prods_merge_new_columns'))
