# %% [markdown]
# # Import libraries and data sets

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/tanu/Desktop/Instacart Basket Analysis/02 Data'

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path,'Prepared data','orders_products_combined.pkl'))

# %%
df_prepared_products = pd.read_csv(os.path.join(path,'Prepared data','products_checked.csv'), index_col = False)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0

# %%
df_orders_products_combined = df_orders_products_combined.rename(columns = {'order_dow' : 'orders_day_of_the_week'}, inplace = False)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2539329        1             1                       2                  8
# 2   2539329        1             1                       2                  8
# 3   2539329        1             1                       2                  8
# 4   2539329        1             1                       2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 9)

# %%
df_prepared_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prepared_products.shape
# Out:
# (49672, 6)

# %%
df_prepared_products = df_prepared_products.drop(['Unnamed: 0'], axis =1)

# %%
df_prepared_products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# # Merging both data sets

# %% [markdown]
# The product_id column is present in both datasets allowing us to merge both the datasets together.
# An inner join will provide the best result in this scenario as it will provide the optimum outcome.

# %%
ords_prods_merge = df_orders_products_combined.merge(df_prepared_products, on = ['product_id'], indicator = 'Match')

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2539329        1             1                       2                  8
# 2   2539329        1             1                       2                  8
# 3   2539329        1             1                       2                  8
# 4   2539329        1             1                       2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
ords_prods_merge['Match'].value_counts()
# Out:
# Match
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # exporting the data set

# %%
ords_prods_merge.to_pickle(os.path.join(path,'Prepared data','ords_prods_merge.pkl'))
