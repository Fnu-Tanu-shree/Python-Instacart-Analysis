# %% [markdown]
# # Order Dataset Merger"

# %%
import pandas as pd
import numpy as np 
import os

# %%
path = r'/Users/tanu/Desktop/Instacart Basket Analysis/02 Data'

# %%
pf_ords_prior = pd.read_csv(os.path.join(path,'Original data','orders_products_prior.csv'), index_col = False)

# %%
df_ords =pd.read_csv(os.path.join(path,'Prepared data','orders_checked.csv'), index_col = False)

# %%
df_ords_prior = pf_ords_prior

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %% [markdown]
# Merging the two datasets

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0                    0           0   2539329        1             1
# 1                    0           0   2539329        1             1
# 2                    0           0   2539329        1             1
# 3                    0           0   2539329        1             1
# 4                    0           0   2539329        1             1
# ...                ...         ...       ...      ...           ...
# 32434484       3421081     3421081   2977660   206209            13
# 32434485       3421081     3421081   2977660   206209            13
# 32434486       3421081     3421081   2977660   206209            13
# 32434487       3421081     3421081   2977660   206209            13
# 32434488       3421081     3421081   2977660   206209            13
#
#           order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_large = df_merged_large.drop(['Unnamed: 0','Unnamed: 0.1','_merge'], axis =1)

# %%
df_merged_large
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 32434484   2977660   206209            13          1                 12
# 32434485   2977660   206209            13          1                 12
# 32434486   2977660   206209            13          1                 12
# 32434487   2977660   206209            13          1                 12
# 32434488   2977660   206209            13          1                 12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered
# ...

# %%
df_merged_large.to_pickle(os.path.join(path,'Prepared data','orders_products_combined.pkl'))
